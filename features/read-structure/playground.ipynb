# %%
import json
from collections import defaultdict

def build_tree(elements):
    # Create a mapping of parent ID to children
    tree = defaultdict(list)
    for element in elements:
        tree[element['parent']].append(element)
    
    # Recursively build a tree structure
    def build_branch(parent_id, depth=0):
        branch = []
        for child in tree[parent_id]:
            branch_str = "  " * depth + f"- {child['type']} (ID: {child['id']}) (Contents: {child['contents']})"
            branch.append(branch_str)
            # Recursively build child branches
            branch.extend(build_branch(child['id'], depth + 1))
        return branch

    # Start building from the root (None)
    return build_branch(None)

# %%
# Load the JSON data from a file
file_path = './metadata-structure-template.json'  # Replace with your file path
with open(file_path, 'r') as file:
    metadata_structure = json.load(file)

# %%
# Build and print the tree structure
tree_structure = build_tree(metadata_structure)
for line in tree_structure:
    print(line)
# Out:
# - child_page (ID: a21f7b0a-6b55-40e5-a803-a828c9943dd4) (Contents: {'title': 'Lily’s Place Eat Eat'})
#   - heading_1 (ID: 6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff) (Contents: {'rich_text': '菜谱&购物清单'})
#     - to_do (ID: 75f41f7d-809e-4c1c-9184-0ba0de8ecbe4) (Contents: {'rich_text': '鸡翅'})
#     - to_do (ID: f65821d1-4286-46af-b625-9c77feae60c1) (Contents: {'rich_text': '培根'})
#     - to_do (ID: 55a8eb84-d262-473d-b095-f912aa45ab16) (Contents: {'rich_text': '金针菇'})
#     - to_do (ID: b6d45699-17ff-4107-a5c9-6952a5b31157) (Contents: {'rich_text': '锡纸'})
#     - to_do (ID: 9d5b6c74-18e6-40fd-bd79-6e53b651a0e5) (Contents: {'rich_text': '🐷带一个烤盘'})
#     - to_do (ID: ecc9da2a-2b88-4bb2-ab71-c6f7d0d3b33c) (Contents: {'rich_text': '凉拌黄瓜丝'})
#     - to_do (ID: d4abce7c-fef8-4284-87c0-5e5b5ef39009) (Contents: {'rich_text': '厚切长条五花肉'})
#     - to_do (ID: c2c9800d-00ad-4b26-9b7f-56d6654d150b) (Contents: {'rich_text': '韩式牛肉片'})
#     - to_do (ID: 0844524e-ed5e-4e36-b09b-71fe86036f93) (Contents: {'rich_text': '炒豆芽'})
#     - to_do (ID: 3bb632f3-d49f-433a-8139-06789ef8241c) (Contents: {'rich_text': '腊肠炒饭'})
#     - to_do (ID: 2ed18c21-11cf-4356-915b-f15a62cb2fc5) (Contents: {'rich_text': '炒土豆丝'})
#     - to_do (ID: b1adc620-5f06-494d-99be-8d96f65ad42b) (Contents: {'rich_text': '一次性盘子&杯子'})
#     - to_do (ID: f88fa756-4ac9-4aa6-b2b8-1931c6a69990) (Contents: {'rich_text': '🍺'})
#     - to_do (ID: 7f986430-78e2-4f0a-bebb-b8c694d15aff) (Contents: {'rich_text': 'Coke Zero - Family Size'})
#     - to_do (ID: 7fb60cfc-8f64-4dfc-87f7-ed4eb5e85013) (Contents: {'rich_text': '薯片Family Size'})
#     - to_do (ID: ce6f78ab-d9c6-4f8b-bce2-b2bd59f4314f) (Contents: {'rich_text': '橙汁儿'})
#     - to_do (ID: 04be2a41-5051-4bae-b276-39d97115f5e8) (Contents: {'rich_text': '西葫芦'})
#     - to_do (ID: df9b147b-79fb-4ee2-b3e7-ab4489a63204) (Contents: {'rich_text': '蒜蓉煎豆腐'})
#     - to_do (ID: 8a337424-402a-40ca-81a7-7bfdfe29d269) (Contents: {'rich_text': '生菜卷烤肉'})
#     - to_do (ID: 16b45e1f-90fc-4f0d-b9d8-6b7191012d9d) (Contents: {'rich_text': '烧烤酱 - 🐷哥酱 & 韩式烧烤酱'})
#     - to_do (ID: 056b8597-4cc0-42cc-8f78-9c6bbe940b79) (Contents: {'rich_text': '香肠'})
#     - to_do (ID: 4134e84f-ee58-4992-b6fe-4bd91932971e) (Contents: {'rich_text': '🐷带垃圾袋'})
#   - heading_1 (ID: 0aad1fe2-f64b-4351-86fd-ef459899ab65) (Contents: {'rich_text': 'Cooking'})
#     - paragraph (ID: fb4e3a2c-1a35-496d-a2c0-dba703007b65) (Contents: {'contents': []})

# %%
metadata_structure
# Out:
# [{'id': '75f41f7d-809e-4c1c-9184-0ba0de8ecbe4',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '鸡翅'}},
#  {'id': 'f65821d1-4286-46af-b625-9c77feae60c1',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '培根'}},
#  {'id': '55a8eb84-d262-473d-b095-f912aa45ab16',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '金针菇'}},
#  {'id': 'b6d45699-17ff-4107-a5c9-6952a5b31157',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '锡纸'}},
#  {'id': '9d5b6c74-18e6-40fd-bd79-6e53b651a0e5',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '🐷带一个烤盘'}},
#  {'id': 'ecc9da2a-2b88-4bb2-ab71-c6f7d0d3b33c',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '凉拌黄瓜丝'}},
#  {'id': 'd4abce7c-fef8-4284-87c0-5e5b5ef39009',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '厚切长条五花肉'}},
#  {'id': 'c2c9800d-00ad-4b26-9b7f-56d6654d150b',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '韩式牛肉片'}},
#  {'id': '0844524e-ed5e-4e36-b09b-71fe86036f93',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '炒豆芽'}},
#  {'id': '3bb632f3-d49f-433a-8139-06789ef8241c',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '腊肠炒饭'}},
#  {'id': '2ed18c21-11cf-4356-915b-f15a62cb2fc5',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '炒土豆丝'}},
#  {'id': 'b1adc620-5f06-494d-99be-8d96f65ad42b',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '一次性盘子&杯子'}},
#  {'id': 'f88fa756-4ac9-4aa6-b2b8-1931c6a69990',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '🍺'}},
#  {'id': '7f986430-78e2-4f0a-bebb-b8c694d15aff',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': 'Coke Zero - Family Size'}},
#  {'id': '7fb60cfc-8f64-4dfc-87f7-ed4eb5e85013',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '薯片Family Size'}},
#  {'id': 'ce6f78ab-d9c6-4f8b-bce2-b2bd59f4314f',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '橙汁儿'}},
#  {'id': '04be2a41-5051-4bae-b276-39d97115f5e8',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '西葫芦'}},
#  {'id': 'df9b147b-79fb-4ee2-b3e7-ab4489a63204',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '蒜蓉煎豆腐'}},
#  {'id': '8a337424-402a-40ca-81a7-7bfdfe29d269',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '生菜卷烤肉'}},
#  {'id': '16b45e1f-90fc-4f0d-b9d8-6b7191012d9d',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '烧烤酱 - 🐷哥酱 & 韩式烧烤酱'}},
#  {'id': '056b8597-4cc0-42cc-8f78-9c6bbe940b79',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '香肠'}},
#  {'id': '4134e84f-ee58-4992-b6fe-4bd91932971e',
#   'type': 'to_do',
#   'url': None,
#   'parent': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'contents': {'rich_text': '🐷带垃圾袋'}},
#  {'id': '6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff',
#   'type': 'heading_1',
#   'url': None,
#   'parent': 'a21f7b0a-6b55-40e5-a803-a828c9943dd4',
#   'contents': {'rich_text': '菜谱&购物清单'}},
#  {'id': '95d39bb7-1c8e-451d-aac7-3879323ac6b1',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Status'],
#     ['Dish'],
#     ['Cook Top'],
#     ['Oven'],
#     ['Air Fryer'],
#     ['Time'],
#     ['Amount']]}},
#  {'id': 'a245292b-041f-4e1a-ad2c-5ee933e21129',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['烤鸡腿'],
#     [],
#     ['200 C'],
#     [],
#     ['25 mins'],
#     ['8 drumsticks']]}},
#  {'id': '3c7a2da3-28a6-49ba-b9ad-8651340f8770',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['培根金针菇'],
#     [],
#     [],
#     ['180 C'],
#     ['8 mins'],
#     ['10']]}},
#  {'id': '4fba2c69-9da2-4770-832d-69030e1ed2b4',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['腊肠炒饭'],
#     ['Big Pan'],
#     [],
#     [],
#     [],
#     ['6 bowls']]}},
#  {'id': 'c072e703-3787-4207-b3f8-d61a5bd5f060',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['炒豆芽菜'],
#     ['Big Pan'],
#     [],
#     [],
#     [],
#     ['3/4 bag']]}},
#  {'id': 'fa6091e8-b12c-4232-876b-933849066099',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['No'], ['炒土豆丝'], ['Big Pan'], [], [], [], []]}},
#  {'id': '6c396cca-047e-4294-bb67-c4d2dc32849e',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['凉拌黄瓜'],
#     [],
#     [],
#     [],
#     [],
#     ['1 whole']]}},
#  {'id': '0c58cc10-4e60-4636-ba6e-87017daee779',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['韩式牛肉片'],
#     [],
#     ['200 C'],
#     [],
#     ['15 mins'],
#     ['1 pack']]}},
#  {'id': '9dfab964-16fc-40e0-8efa-0245946ef498',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['Yes'],
#     ['西葫芦'],
#     [],
#     ['200 C'],
#     [],
#     ['18 mins'],
#     ['2']]}},
#  {'id': 'fc3f3b67-7d98-4e52-b367-7c2316ce5c00',
#   'type': 'table_row',
#   'url': None,
#   'parent': 'c339e795-e827-41c9-9fe9-6d36fc93e108',
#   'contents': {'subTypeObj': [['No'],
#     ['蒜蓉煎豆腐'],
#     ['Small Pan'],
#     [],
#     [],
#     [],
#     []]}},
#  {'id': 'fb4e3a2c-1a35-496d-a2c0-dba703007b65',
#   'type': 'paragraph',
#   'url': None,
#   'parent': '0aad1fe2-f64b-4351-86fd-ef459899ab65',
#   'contents': {'contents': []}},
#  {'id': '0aad1fe2-f64b-4351-86fd-ef459899ab65',
#   'type': 'heading_1',
#   'url': None,
#   'parent': 'a21f7b0a-6b55-40e5-a803-a828c9943dd4',
#   'contents': {'rich_text': 'Cooking'}},
#  {'id': 'a21f7b0a-6b55-40e5-a803-a828c9943dd4',
#   'type': 'child_page',
#   'url': 'https://www.notion.so/a21f7b0a6b5540e5a803a828c9943dd4',
#   'parent': None,
#   'contents': {'title': 'Lily’s Place Eat Eat'}}]

# %%
tree_structure
# Out:
# ["- child_page (ID: a21f7b0a-6b55-40e5-a803-a828c9943dd4) (Contents: {'title': 'Lily’s Place Eat Eat'})",
#  "  - heading_1 (ID: 6a34cc9a-c8a9-4d1e-804f-a9b45883d5ff) (Contents: {'rich_text': '菜谱&购物清单'})",
#  "    - to_do (ID: 75f41f7d-809e-4c1c-9184-0ba0de8ecbe4) (Contents: {'rich_text': '鸡翅'})",
#  "    - to_do (ID: f65821d1-4286-46af-b625-9c77feae60c1) (Contents: {'rich_text': '培根'})",
#  "    - to_do (ID: 55a8eb84-d262-473d-b095-f912aa45ab16) (Contents: {'rich_text': '金针菇'})",
#  "    - to_do (ID: b6d45699-17ff-4107-a5c9-6952a5b31157) (Contents: {'rich_text': '锡纸'})",
#  "    - to_do (ID: 9d5b6c74-18e6-40fd-bd79-6e53b651a0e5) (Contents: {'rich_text': '🐷带一个烤盘'})",
#  "    - to_do (ID: ecc9da2a-2b88-4bb2-ab71-c6f7d0d3b33c) (Contents: {'rich_text': '凉拌黄瓜丝'})",
#  "    - to_do (ID: d4abce7c-fef8-4284-87c0-5e5b5ef39009) (Contents: {'rich_text': '厚切长条五花肉'})",
#  "    - to_do (ID: c2c9800d-00ad-4b26-9b7f-56d6654d150b) (Contents: {'rich_text': '韩式牛肉片'})",
#  "    - to_do (ID: 0844524e-ed5e-4e36-b09b-71fe86036f93) (Contents: {'rich_text': '炒豆芽'})",
#  "    - to_do (ID: 3bb632f3-d49f-433a-8139-06789ef8241c) (Contents: {'rich_text': '腊肠炒饭'})",
#  "    - to_do (ID: 2ed18c21-11cf-4356-915b-f15a62cb2fc5) (Contents: {'rich_text': '炒土豆丝'})",
#  "    - to_do (ID: b1adc620-5f06-494d-99be-8d96f65ad42b) (Contents: {'rich_text': '一次性盘子&杯子'})",
#  "    - to_do (ID: f88fa756-4ac9-4aa6-b2b8-1931c6a69990) (Contents: {'rich_text': '🍺'})",
#  "    - to_do (ID: 7f986430-78e2-4f0a-bebb-b8c694d15aff) (Contents: {'rich_text': 'Coke Zero - Family Size'})",
#  "    - to_do (ID: 7fb60cfc-8f64-4dfc-87f7-ed4eb5e85013) (Contents: {'rich_text': '薯片Family Size'})",
#  "    - to_do (ID: ce6f78ab-d9c6-4f8b-bce2-b2bd59f4314f) (Contents: {'rich_text': '橙汁儿'})",
#  "    - to_do (ID: 04be2a41-5051-4bae-b276-39d97115f5e8) (Contents: {'rich_text': '西葫芦'})",
#  "    - to_do (ID: df9b147b-79fb-4ee2-b3e7-ab4489a63204) (Contents: {'rich_text': '蒜蓉煎豆腐'})",
#  "    - to_do (ID: 8a337424-402a-40ca-81a7-7bfdfe29d269) (Contents: {'rich_text': '生菜卷烤肉'})",
#  "    - to_do (ID: 16b45e1f-90fc-4f0d-b9d8-6b7191012d9d) (Contents: {'rich_text': '烧烤酱 - 🐷哥酱 & 韩式烧烤酱'})",
#  "    - to_do (ID: 056b8597-4cc0-42cc-8f78-9c6bbe940b79) (Contents: {'rich_text': '香肠'})",
#  "    - to_do (ID: 4134e84f-ee58-4992-b6fe-4bd91932971e) (Contents: {'rich_text': '🐷带垃圾袋'})",
#  "  - heading_1 (ID: 0aad1fe2-f64b-4351-86fd-ef459899ab65) (Contents: {'rich_text': 'Cooking'})",
#  "    - paragraph (ID: fb4e3a2c-1a35-496d-a2c0-dba703007b65) (Contents: {'contents': []})"]
